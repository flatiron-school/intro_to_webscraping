# %%
# Webscraping
import requests
from bs4 import BeautifulSoup

# Data organization
import pandas

# Visualization
import matplotlib

# %%
url = 'https://en.wikipedia.org/wiki/Lis_of_current_United_States_senators'
response = requests.get(url).text
soup = BeautifulSoup(response, 'lxml')

# %%
soup.
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Lis of current United States senators - Wikipedia</title>
# ...
